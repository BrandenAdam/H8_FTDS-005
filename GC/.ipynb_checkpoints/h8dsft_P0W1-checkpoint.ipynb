# %% [markdown]
# # INTRODUCTION

# %% [markdown]
# Hello my name is Branden, and i'm gonna  analyze this datasets using only numpy and pandas.

# %% [markdown]
# This data set includes 721 Pokemon, including their number, name, first and second type, and basic stats: HP, Attack, Defense, Special Attack, Special Defense, and Speed.
#
# The data feature is: <br>
# #: ID for each pokemon <br>
# Name: Name of each pokemon <br>
# Type 1: Each pokemon has a type, this determines weakness/resistance to attacks <br>
# Type 2: Some pokemon are dual type and have 2 <br>
# Total: sum of all stats that come after this, a general guide to how strong a pokemon is <br>
# HP: hit points, or health, defines how much damage a pokemon can withstand before fainting <br>
# Attack: the base modifier for normal attacks (eg. Scratch, Punch) <br>
# Defense: the base damage resistance against normal attacks <br>
# SP Atk: special attack, the base modifier for special attacks (e.g. fire blast, bubble beam) <br>
# SP Def: the base damage resistance against special attacks <br>
# Speed: determines which pokemon attacks first each round <br>

# %% [markdown]
# # OBJECTIVE

# %% [markdown]
# Which pokemon have glasscanon status? <br>
# Any Legendary Dragon in generation 6? <br>
# Which pokemon have high status? and how many are there if grouped by legendary? <br>
# How many pokemon are legendary and non-legendary? <br>
# What is the mean of pokemon status in each generation? <br>
# How many pokemon type combination are there in the data? <br>
# Are there any pokemon who have same status or parameter? <br>

# %%
import numpy as np
import pandas as pd


data = pd.read_csv("./datasets/Pokemon.csv")
data.columns = ["index", "name", "type_1", "type_2", "total", "hp", "attack", "defense", 
                "sp_atk", "sp_def", "speed", "generation", "legendary"]

categorical = ["name", "type_1", "type_2", "legendary"]
numeric = [i for i in data if i not in categorical]

# change nan value of categorical data to None rather than just remove it and change nan value of numerical to median of the column
data[categorical] = data[categorical].fillna("None")
data[numeric] = data[numeric].fillna(data[numeric].median())

# drop data
data.drop({'index',}, axis = 1, inplace=True)
print(len(data))
# Out:
# 800

# %%
data.head(15)
# Out:
#                          name type_1  type_2  total  hp  attack  defense  \
# 0                   Bulbasaur  Grass  Poison    318  45      49       49
# 1                     Ivysaur  Grass  Poison    405  60      62       63
# 2                    Venusaur  Grass  Poison    525  80      82       83
# 3       VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 4                  Charmander   Fire    None    309  39      52       43
# 5                  Charmeleon   Fire    None    405  58      64       58
# 6                   Charizard   Fire  Flying    534  78      84       78
# 7   CharizardMega Charizard X   Fire  Dragon    634  78     130      111
# 8   CharizardMega Charizard Y   Fire  Flying    634  78     104       78
# 9                    Squirtle  Water    None    314  44      48       65
# 10                  Wartortle  Water    None    405  59      63       80
# 11                  Blastoise  Water    None    530  79      83      100
# ...

# %%
data[(data["attack"] >= 100) & (data["sp_atk"] >= 100) & (data["defense"] <= 50) & (data["sp_def"] <= 50)]
# Out:
#                      name   type_1 type_2  total  hp  attack  defense  sp_atk  \
# 428    DeoxysNormal Forme  Psychic   None    600  50     150       50     150
# 429    DeoxysAttack Forme  Psychic   None    600  50     180       20     180
# 750  AegislashBlade Forme    Steel  Ghost    520  60     150       50     150
#
#      sp_def  speed  generation  legendary
# 428      50    150           3       True
# 429      20    150           3       True
# 750      50     60           6      False

# %%
data[(data["type_1"] == "Dragon") & (data["generation"] == 6) & (data["legendary"] == True)]
# Out:
#                  name  type_1  type_2  total   hp  attack  defense  sp_atk  \
# 794  Zygarde50% Forme  Dragon  Ground    600  108     100      121      81
#
#      sp_def  speed  generation  legendary
# 794      95     95           6       True

# %%
data[(data["defense"] >= 100) & (data["sp_def"] >= 100) & (data["attack"] >= 100) & (data["sp_atk"] >= 100) & (data["speed"] >= 100)]["name"].tolist()
# Out:
# ['MewtwoMega Mewtwo X',
#  'Mew',
#  'Celebi',
#  'MetagrossMega Metagross',
#  'LatiasMega Latias',
#  'LatiosMega Latios',
#  'RayquazaMega Rayquaza',
#  'Jirachi',
#  'Palkia',
#  'Manaphy',
#  'ShayminLand Forme',
#  'Arceus',
#  'Victini',
#  'DiancieMega Diancie']

# %%
data[(data["defense"] >= 100) & (data["sp_def"] >= 100) & (data["attack"] >= 100) & (data["sp_atk"] >= 100)].groupby("legendary").size()
# Out:
# legendary
# False     9
# True     17
# dtype: int64

# %%
test = data[(data["defense"] >= 100) & (data["sp_def"] >= 100) & (data["attack"] >= 100) & (data["sp_atk"] >= 100)]
import matplotlib
ax = test.plot.bar(x = "name", y = "total")

# %%
data.groupby("legendary").size()

# %%
data.groupby("generation").mean()

# %%
data.groupby(["type_1", "type_2"]).size().count()

# %%
data_dp = data.drop({'name', 'generation'}, axis = 1)

# %%
print(len(data_dp.drop_duplicates()))
data_dp.head()
duplicate = data_dp[data_dp.duplicated(keep=False)]
print(duplicate)

# %%
list = duplicate.index.tolist()
data.iloc[list]

# %% [markdown]
# # CONCLUSION

# %% [markdown]
# Which pokemon have glasscanon status? <br>
# -DeoxysNormal Forme, DeoxysAttack, AegislashBlade <br>
#
# Any Legendary Dragon in generation 6? <br>
# -Yes, there is only one pokemon called Zygarde50% Forme <br>
#
# Which pokemon have high status? and how many are there if grouped by legendary? <br>
# -MewtwoMega Mewtwo X,
# Mew,
# Celebi,
# MetagrossMega Metagross,
# LatiasMega Latias,
# LatiosMega Latios,
# RayquazaMega Rayquaza'
# Jirachi,
# Palkia,
# Manaphy,
# ShayminLand Forme,
# Arceus,
# Victini,
# DiancieMega Diancie <br>
#
# How many pokemon are legendary and non-legendary?<br>
# -Legendary 17, Non-Legendary: 9 <br>
#
# What is the mean of pokemon status in each generation? <br>
# 1	426.813253	65.819277	76.638554	70.861446	71.819277	69.090361	72.584337	0.036145 <br>
# 2	418.283019	71.207547	72.028302	73.386792	65.943396	73.905660	61.811321	0.047170 <br>
# 3	436.225000	66.543750	81.625000	74.100000	75.806250	71.225000	66.925000	0.112500 <br>
# 4	459.016529	73.082645	82.867769	78.132231	76.404959	77.190083	71.338843	0.107438 <br>
# 5	434.987879	71.787879	82.066667	72.327273	71.987879	68.739394	68.078788	0.090909 <br>
# 6	436.378049	68.268293	75.804878	76.682927	74.292683	74.890244	66.439024	0.097561 <br>
#
# How many pokemon type combination are there in the data? <br>
# 154 <br>
#
# Are there any pokemon who have same status or parameter? <br>
# Yes

# %% [markdown]
# There are 800 pokemon dataset row count when the original provider said there are 721 pokemon but it's the result of many form of one pokemon depending on their state. Each Pokemon excluding it's different form depending on their state raw status including it's type combination and legendary status is almost 100% unique. There are also many pokemon with high status (all above 100) in each parameter for both legendary and non-legendary pokemon. We can use this datasets to calculate damage or find any pokemon with the status parameter that you want.
